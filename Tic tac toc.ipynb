# %%
board=[' ' for i in range(9)]

# %%
def check_win():
       
            if(board[0]==board[1] and board[1]==board[2] and board[2]==board[0] and board[1]!=' '):
                    return True
            elif(board[4]==board[3] and board[5]==board[4] and board[3]==board[4] and board[4]!=' '):
                    return True
            elif(board[6]==board[7] and board[8]==board[7] and board[8]==board[6] and board[7]!=' '):
                    return True
            elif(board[0]==board[3] and board[3]==board[6] and board[0]==board[6] and board[6]!=' '):
                    return True
            elif(board[1]==board[4] and board[4]==board[7] and board[1]==board[7] and board[7]!=' '):
                    return True
            elif(board[2]==board[5] and board[5]==board[8] and board[2]==board[8] and board[2]!=' '):
                    return True
            elif(board[0]==board[4] and board[4]==board[8] and board[0]==board[8] and board[0]!=' '):
                    return True
            elif(board[2]==board[4] and board[4]==board[6] and board[2]==board[6] and board[2]!=' '):
                    return True
            else:
                return False

# %%
def check_tie():
    if(board[0]!=' ' and board[2]!=' ' and board[3]!=' ' and board[4]!=' ' and board[5]!=' ' and board[6]!=' ' and board[7]!=' ' and board[8]!=' ' and board[1]!=' '):    
        return True

# %%
def check_position(p): 
    if(board[p]==' '):
        return True
    else:
        return False

# %%
def print_board():
        print(" %c | %c | %c "%(board[0],board[1],board[2]))
        print("___|___|___")    
        print(" %c | %c | %c "%(board[3],board[4],board[5]))
        print("___|___|___")    
        print(" %c | %c | %c "%(board[6],board[7],board[8]))
        print("   |   |   ")      
        print('\n')

# %%
print("The Game Of Tic-Tac-Toc")
# Out:
# The Game Of Tic-Tac-Toc

# %%
count=1
while True:
    if(count%2==0):
        x='X'
    else :
        x='O'
    try:
        p=int(input("Enter the place you would to play from [0 to 8] : "))
    except:
        print("Enter vlaid value!\n")
        continue
    if(check_position(p)==False):
        print("This position is not available !\n")
        continue
    board[p]=x
    print_board()
    if(check_win()):
        print(x," is Win\n")
        board=[' ' for i in range(9)]
        print("**The Game Of Tic-Tac-Toc**\n")
        count=0
    elif(check_tie()):
        print("The Game is End\n")
        board=[' ' for i in range(9)]
        print("**The Game Of Tic-Tac-Toc**\n")
        count=0
    count+=1
# Out:
# Enter the place you would to play from [0 to 8] : a
# Enter vlaid value!
#
# Enter the place you would to play from [0 to 8] : 1
#    | O |
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 0
#  X | O |
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 3
#  X | O |
# ___|___|___
#  O |   |
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 5
#  X | O |
# ___|___|___
#  O |   | X
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 5
# This position is not available !
#
# Enter the place you would to play from [0 to 8] : 6
#  X | O |
# ___|___|___
#  O |   | X
# ___|___|___
#  O |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 7
#  X | O |
# ___|___|___
#  O |   | X
# ___|___|___
#  O | X |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 8
#  X | O |
# ___|___|___
#  O |   | X
# ___|___|___
#  O | X | O
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 3
# This position is not available !
#
# Enter the place you would to play from [0 to 8] : 2
#  X | O | X
# ___|___|___
#  O |   | X
# ___|___|___
#  O | X | O
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 4
#  X | O | X
# ___|___|___
#  O | O | X
# ___|___|___
#  O | X | O
#    |   |
#
#
# The Game is End
#
# **The Game Of Tic-Tac-Toc**
#
# Enter the place you would to play from [0 to 8] : 1
#    | O |
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 2
#    | O | X
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 4
#    | O | X
# ___|___|___
#    | O |
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 5
#    | O | X
# ___|___|___
#    | O | X
# ___|___|___
#    |   |
#    |   |
#
#
# Enter the place you would to play from [0 to 8] : 7
#    | O | X
# ___|___|___
#    | O | X
# ___|___|___
#    | O |
#    |   |
#
#
# O  is Win
#
# **The Game Of Tic-Tac-Toc**
